# %%
import pandas as pd

# %%
s1 = pd.read_csv("s2_final.csv")
s1.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s2 = pd.read_csv("s3_final.csv")
s2.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s3 = pd.read_csv("s4_final.csv")
s3.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s4 = pd.read_csv("s5_final.csv")
s4.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s5 = pd.read_csv("s6_final.csv")
s5.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s6 = pd.read_csv("s7_final.csv")
s6.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s7 = pd.read_csv("s8_final.csv")
s7.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s8 = pd.read_csv("s9_final.csv")
s8.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s9 = pd.read_csv("s10_final.csv")
s9.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s10 = pd.read_csv("s11_final.csv")
s10.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s11 = pd.read_csv("s13_final.csv")
s11.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s12 = pd.read_csv("s14_final.csv")
s12.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s13 = pd.read_csv("s15_final.csv")
s13.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s14 = pd.read_csv("s16_final.csv")
s14.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s15 = pd.read_csv("s17_final.csv")
s15.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress
# 0 -0.012497 -1.899719   High
# 1 -0.012543  2.058411   High
# 2  0.002426 -2.027893   High
# 3  0.004532  0.958252   High
# 4  0.014969 -0.382996   High

# %%
s1["Subject"] = "S1"
s1.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S1
# 1 -0.012543  2.058411   High      S1
# 2  0.002426 -2.027893   High      S1
# 3  0.004532  0.958252   High      S1
# 4  0.014969 -0.382996   High      S1

# %%
s2["Subject"] = "S2"
s2.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S2
# 1 -0.012543  2.058411   High      S2
# 2  0.002426 -2.027893   High      S2
# 3  0.004532  0.958252   High      S2
# 4  0.014969 -0.382996   High      S2

# %%
s3["Subject"] = "S3"
s3.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S3
# 1 -0.012543  2.058411   High      S3
# 2  0.002426 -2.027893   High      S3
# 3  0.004532  0.958252   High      S3
# 4  0.014969 -0.382996   High      S3

# %%
s4["Subject"] = "S4"
s4.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S4
# 1 -0.012543  2.058411   High      S4
# 2  0.002426 -2.027893   High      S4
# 3  0.004532  0.958252   High      S4
# 4  0.014969 -0.382996   High      S4

# %%
s5["Subject"] = "S5"
s5.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S5
# 1 -0.012543  2.058411   High      S5
# 2  0.002426 -2.027893   High      S5
# 3  0.004532  0.958252   High      S5
# 4  0.014969 -0.382996   High      S5

# %%
s6["Subject"] = "S6"
s6.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S6
# 1 -0.012543  2.058411   High      S6
# 2  0.002426 -2.027893   High      S6
# 3  0.004532  0.958252   High      S6
# 4  0.014969 -0.382996   High      S6

# %%
s7["Subject"] = "S7"
s7.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S7
# 1 -0.012543  2.058411   High      S7
# 2  0.002426 -2.027893   High      S7
# 3  0.004532  0.958252   High      S7
# 4  0.014969 -0.382996   High      S7

# %%
s8["Subject"] = "S8"
s8.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S8
# 1 -0.012543  2.058411   High      S8
# 2  0.002426 -2.027893   High      S8
# 3  0.004532  0.958252   High      S8
# 4  0.014969 -0.382996   High      S8

# %%
s9["Subject"] = "S9"
s9.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High      S9
# 1 -0.012543  2.058411   High      S9
# 2  0.002426 -2.027893   High      S9
# 3  0.004532  0.958252   High      S9
# 4  0.014969 -0.382996   High      S9

# %%
s10["Subject"] = "S10"
s10.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S10
# 1 -0.012543  2.058411   High     S10
# 2  0.002426 -2.027893   High     S10
# 3  0.004532  0.958252   High     S10
# 4  0.014969 -0.382996   High     S10

# %%
s11["Subject"] = "S11"
s11.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S11
# 1 -0.012543  2.058411   High     S11
# 2  0.002426 -2.027893   High     S11
# 3  0.004532  0.958252   High     S11
# 4  0.014969 -0.382996   High     S11

# %%
s12["Subject"] = "S12"
s12.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S12
# 1 -0.012543  2.058411   High     S12
# 2  0.002426 -2.027893   High     S12
# 3  0.004532  0.958252   High     S12
# 4  0.014969 -0.382996   High     S12

# %%
s13["Subject"] = "S13"
s13.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S13
# 1 -0.012543  2.058411   High     S13
# 2  0.002426 -2.027893   High     S13
# 3  0.004532  0.958252   High     S13
# 4  0.014969 -0.382996   High     S13

# %%
s14["Subject"] = "S14"
s14.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S14
# 1 -0.012543  2.058411   High     S14
# 2  0.002426 -2.027893   High     S14
# 3  0.004532  0.958252   High     S14
# 4  0.014969 -0.382996   High     S14

# %%
s15["Subject"] = "S15"
s15.head()
# Out:
#    Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 0     1829273  0.8978  0.0530  0.0216  32.370544  9.555435 -0.065140
# 1     1673905  0.8922  0.1310  0.0086  34.081850  8.810806 -0.042526
# 2     1587320  0.9006  0.0358  0.1310  32.058228  6.883621 -0.342453
# 3     1688454  0.9286  0.0734  0.0446  34.347473  8.009720 -0.078461
# 4     1851496  0.9122  0.0210  0.0282  32.084960  9.450531  0.116272
#
#         EMG      RESP Stress Subject
# 0 -0.012497 -1.899719   High     S15
# 1 -0.012543  2.058411   High     S15
# 2  0.002426 -2.027893   High     S15
# 3  0.004532  0.958252   High     S15
# 4  0.014969 -0.382996   High     S15

# %%
print(s1.shape)
print(s2.shape)
print(s3.shape)
print(s4.shape)
print(s5.shape)
print(s6.shape)
print(s7.shape)
print(s8.shape)
print(s9.shape)
print(s10.shape)
print(s11.shape)
print(s12.shape)
print(s13.shape)
print(s14.shape)
print(s15.shape)
# Out:
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)
# (15000, 11)

# %%
s1 = s1.sample(15000)
s2 = s2.sample(15000)
s3 = s3.sample(15000)
s4 = s4.sample(15000)
s5 = s5.sample(15000)
s6 = s6.sample(15000)
s7 = s7.sample(15000)
s8 = s8.sample(15000)
s9 = s9.sample(15000)
s10 = s10.sample(15000)
s11 = s11.sample(15000)
s12 = s12.sample(15000)
s13 = s13.sample(15000)
s14 = s14.sample(15000)
s15 = s15.sample(15000)

# %%
dataset = pd.concat([ s1 , s2 , s3 , s4,
                                     s5 , s6 , s7,
                                     s8 , s9 , s10,
                                     s11 , s13 ,s14,
                                     s15 ] )

# %%
dataset
# Out:
#        Unnamed: 0       X       Y       Z       TEMP       EDA       ECG  \
# 10999     3498571  0.9150 -0.1474 -0.0546  32.287140  0.683594  0.002518
# 12049     3542509  0.8974 -0.1454 -0.1794  32.597350  0.698471 -0.028152
# 10156     3452655  0.9116 -0.1426 -0.0678  31.946991  0.814056 -0.155090
# 10073     3471747  0.9118 -0.1468 -0.0458  32.166656  0.716400  0.016342
# 6704      3995245  0.4494 -0.2418 -0.8390  32.047850  0.538635  0.024948
# ...           ...     ...     ...     ...        ...       ...       ...
# 10281     1383595  0.8778 -0.0290 -0.2728  33.620117  5.929565 -0.345291
# 2732      1778327  0.9124  0.0198  0.0122  33.558075  7.802200 -0.034058
# 3860      1855487  0.9006  0.0082  0.0194  32.028564  9.389114  0.075897
# 11871     1383086  0.8738 -0.0274 -0.2890  33.556520  5.934143 -0.104416
# 14547     1445512  0.8814 -0.0250 -0.2698  33.496033  5.950165 -0.169327
#
#             EMG      RESP  Stress Subject
# 10999  0.012634  1.422119  Medium      S1
# ...

# %%
dataset.shape
# Out:
# (210000, 11)

# %%
dataset["Stress"].value_counts()
# Out:
# Stress
# Medium    70000
# Low       70000
# High      70000
# Name: count, dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.duplicated()
# Out:
# 10999    False
# 12049    False
# 10156    False
# 10073    False
# 6704     False
#          ...
# 10281    False
# 2732     False
# 3860     False
# 11871    False
# 14547    False
# Length: 210000, dtype: bool

# %%
dataset = dataset.sample(len(dataset))

# %%
dataset.head(20)
# Out:
#        Unnamed: 0       X       Y       Z       TEMP        EDA       ECG  \
# 4696      1598539  0.9150 -0.0066  0.0116  32.074585   6.941605 -0.119156
# 7105      1867926  0.8312  0.0022 -0.4290  34.989563   3.730392 -0.021744
# 12164     1163119  0.7162  0.0198 -0.6094  34.482147   0.926971  0.000549
# 6849      3547746  0.4724  0.0238 -0.8394  34.818512   2.827454 -0.007095
# 7430      4299869  0.8498 -0.0086 -0.3550  33.402374   7.197571 -0.266785
# 6587      1910680  0.8434 -0.0468 -0.3706  34.042236   2.959824 -0.023392
# 12274     3407614  0.9142 -0.1414 -0.0734  32.203857   0.931931 -0.163467
# 4535      1914599  0.9166  0.0230 -0.0022  31.828491   8.330917 -0.203293
# 8344      3192096  0.9022 -0.0074 -0.1750  32.938750   7.112885  0.013962
# 8979      3470051  0.3934  0.0194 -0.8904  34.743103   2.904510 -0.054153
# 4987      1629209  0.9102  0.0324  0.0376  32.200867   7.823563 -0.144699
# 10807     1332972  0.8874 -0.0342 -0.2526  33.544434   6.032562 -0.053513
# ...

# %%
dataset.drop(columns= "Unnamed: 0")
# Out:
#             X       Y       Z       TEMP       EDA       ECG       EMG  \
# 4696   0.9150 -0.0066  0.0116  32.074585  6.941605 -0.119156  0.008011
# 7105   0.8312  0.0022 -0.4290  34.989563  3.730392 -0.021744 -0.000687
# 12164  0.7162  0.0198 -0.6094  34.482147  0.926971  0.000549 -0.002151
# 6849   0.4724  0.0238 -0.8394  34.818512  2.827454 -0.007095 -0.003845
# 7430   0.8498 -0.0086 -0.3550  33.402374  7.197571 -0.266785  0.002884
# ...       ...     ...     ...        ...       ...       ...       ...
# 11529  0.9098  0.0838 -0.0126  33.354095  7.783127 -0.292923  0.001236
# 6181   0.8498 -0.0038 -0.3502  33.358612  7.272339  0.018494 -0.003708
# 7979   0.8282 -0.0414 -0.4088  34.141327  2.912140 -0.157242 -0.001236
# 11555  0.8552  0.0130 -0.3390  34.994200  6.295395 -0.186356 -0.011032
# 14803  0.9186 -0.1196 -0.1802  34.191650  2.862930 -0.096497  0.015244
#
#            RESP  Stress Subject
# 4696  -0.538635    High     S14
# 7105  -2.604675     Low      S7
# ...

# %% [markdown]
# dataset.to_csv("stress_analysis.csv")

# %%
#Stress_Detection_Dataset.to_csv("Stress_Detection_Dataset.csv")

# %% [raw]
# dataset.head()

# %% [raw]
# Stress_Detection_Dataset[Stress_Detection_Dataset.duplicated()]

# %% [raw]
# Stress_Detection_Dataset[Stress_Detection_Dataset.duplicated()]

# %% [raw]
# dataset = pd.read_csv("stress_analysis.csv")
# dataset.head()

# %% [raw]
# dataset.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="ECG" , y = "EMG" , data=s14 , hue="Stress")
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.kdeplot(data=s12, x="TEMP", hue='Stress', fill=True, common_norm=False, palette="coolwarm")
plt.tight_layout()
plt.show()
