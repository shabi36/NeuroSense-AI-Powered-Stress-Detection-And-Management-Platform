# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Stress_Detection_Dataset.csv")
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
dataset.drop(columns=["Unnamed: 0" ,"Unnamed: 0.1"] , inplace= True)

# %%
dataset.head()
# Out:
#         X       Y       Z       TEMP       EDA       ECG       EMG      RESP  \
# 0  0.9050  0.0344  0.0418  31.889160  8.601761 -0.032547  0.013321 -2.703857
# 1  0.9138 -0.1422 -0.0694  32.227600  0.884628  0.020691 -0.004303 -2.252197
# 2  0.4426 -0.2440 -0.8464  32.010742  0.529099  0.079330  0.007462  1.069641
# 3  0.4248 -0.2466 -0.8498  31.936615  0.453949 -0.040970 -0.018173  2.943420
# 4  0.9326  0.0386  0.0030  32.217224  7.914734 -0.292007 -0.006729 -0.753784
#
#    Stress
# 0       3
# 1       2
# 2       1
# 3       1
# 4       3

# %%
dataset.shape
# Out:
# (225000, 9)

# %%
dataset.isnull().sum()
# Out:
# X         0
# Y         0
# Z         0
# TEMP      0
# EDA       0
# ECG       0
# EMG       0
# RESP      0
# Stress    0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225000 entries, 0 to 224999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   X       225000 non-null  float64
#  1   Y       225000 non-null  float64
#  2   Z       225000 non-null  float64
#  3   TEMP    225000 non-null  float64
#  4   EDA     225000 non-null  float64
#  5   ECG     225000 non-null  float64
#  6   EMG     225000 non-null  float64
#  7   RESP    225000 non-null  float64
#  8   Stress  225000 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 15.4+ MB

# %%
dataset.describe()
# Out:
#                    X              Y              Z           TEMP  \
# count  225000.000000  225000.000000  225000.000000  225000.000000
# mean        0.816646      -0.004196      -0.266615      33.607337
# std         0.129467       0.072809       0.314513       1.107826
# min         0.334200      -0.350600      -0.955800      31.270782
# 25%         0.760400      -0.035400      -0.467800      32.561493
# 50%         0.872800       0.008800      -0.254600      33.966125
# 75%         0.906000       0.033000       0.012000      34.437714
# max         1.303800       0.388600       0.732600      35.682922
#
#                  EDA            ECG            EMG           RESP
# count  225000.000000  225000.000000  225000.000000  225000.000000
# mean        5.798486      -0.001085      -0.003175       0.032415
# std         3.143063       0.272254       0.019906       4.058577
# min         0.449371      -1.314606      -0.452957     -36.167908
# 25%         2.916622      -0.095627      -0.010025      -2.247620
# 50%         6.477737      -0.028290      -0.002563      -0.242615
# 75%         8.147812       0.025589       0.003937       2.183533
# max        13.466263       1.499496       0.358017      32.131958

# %%
sns.displot(dataset["X"])

# %%
sns.boxplot(dataset["X"])
# Out:
# <Axes: ylabel='X'>

# %%
sns.scatterplot(dataset["X"])
# Out:
# <Axes: ylabel='X'>

# %%
q1 = dataset["X"].quantile(0.25)
q3 = dataset["X"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)
# Out:
# 0.5420001149177551
# 1.1243999600410461

# %%
dataset[dataset["X"] < 0.54]
# Out:
#              X       Y       Z       TEMP       EDA       ECG       EMG  \
# 2       0.4426 -0.2440 -0.8464  32.010742  0.529099  0.079330  0.007462
# 3       0.4248 -0.2466 -0.8498  31.936615  0.453949 -0.040970 -0.018173
# 10      0.4494 -0.2430 -0.8414  32.082000  0.564957 -0.010437 -0.003983
# 13      0.4548 -0.2430 -0.8370  32.153260  0.615311  0.033005  0.000412
# 20      0.4694 -0.2504 -0.8206  32.187470  0.669479  0.114853  0.004715
# ...        ...     ...     ...        ...       ...       ...       ...
# 224977  0.4424  0.0264 -0.8702  33.934204  7.149124 -0.068665 -0.008011
# 224978  0.4304  0.0212 -0.8594  34.023956  7.060242  0.723312 -0.003983
# 224983  0.4084  0.0190 -0.8778  34.048340  7.009506  0.255203 -0.010574
# 224987  0.4956  0.0408 -0.8086  33.914430  7.181168 -0.166306 -0.006226
# 224994  0.3742  0.0302 -0.8858  33.650390  6.169510 -0.192810  0.011765
#
#             RESP Stress
# 2       1.069641    Low
# 3       2.943420    Low
# 10     -0.798035    Low
# 13     -1.885986    Low
# 20     -1.039124    Low
# ...          ...    ...
# 224977  3.150940    Low
# 224978  7.981873    Low
# 224983 -0.462341    Low
# 224987 -4.730225    Low
# 224994  8.152771    Low
#
# [12743 rows x 9 columns]

# %%
sns.displot(dataset["Y"])

# %%
sns.boxplot(dataset["X"])
# Out:
# <Axes: ylabel='X'>

# %%
sns.scatterplot(dataset["X"])
# Out:
# <Axes: ylabel='X'>

# %%
q1 = dataset["Y"].quantile(0.25)
q3 = dataset["Y"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)
# Out:
# -0.13799992203712436
# 0.13559994101524325

# %%
sns.boxplot(dataset["Z"])

# %%
sns.scatterplot(dataset["Z"])

# %%
sns.displot(dataset["X"])

# %%
q1 = dataset["Z"].quantile(0.25)
q3 = dataset["Z"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#         X       Y       Z       TEMP       EDA       ECG       EMG      RESP  \
# 0  0.9050  0.0344  0.0418  31.889160  8.601761 -0.032547  0.013321 -2.703857
# 1  0.9138 -0.1422 -0.0694  32.227600  0.884628  0.020691 -0.004303 -2.252197
# 2  0.4426 -0.2440 -0.8464  32.010742  0.529099  0.079330  0.007462  1.069641
# 3  0.4248 -0.2466 -0.8498  31.936615  0.453949 -0.040970 -0.018173  2.943420
# 4  0.9326  0.0386  0.0030  32.217224  7.914734 -0.292007 -0.006729 -0.753784
#
#    Stress
# 0    High
# 1  Medium
# 2     Low
# 3     Low
# 4    High

# %%
sns.scatterplot(dataset["TEMP"])

# %%
sns.scatterplot(dataset["TEMP"])

# %%
sns.scatterplot(dataset["TEMP"])

# %%
q1 = dataset["TEMP"].quantile(0.25)
q3 = dataset["TEMP"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#         X       Y       Z       TEMP       EDA       ECG       EMG      RESP  \
# 0  0.9050  0.0344  0.0418  31.889160  8.601761 -0.032547  0.013321 -2.703857
# 1  0.9138 -0.1422 -0.0694  32.227600  0.884628  0.020691 -0.004303 -2.252197
# 2  0.4426 -0.2440 -0.8464  32.010742  0.529099  0.079330  0.007462  1.069641
# 3  0.4248 -0.2466 -0.8498  31.936615  0.453949 -0.040970 -0.018173  2.943420
# 4  0.9326  0.0386  0.0030  32.217224  7.914734 -0.292007 -0.006729 -0.753784
#
#    Stress
# 0    High
# 1  Medium
# 2     Low
# 3     Low
# 4    High

# %%
sns.displot(dataset["EDA"])

# %%
sns.boxplot(dataset["EDA"])

# %%
sns.scatterplot(dataset["EDA"])

# %%
q1 = dataset["EDA"].quantile(0.25)
q3 = dataset["EDA"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
sns.displot(dataset["ECG"])

# %%
sns.boxplot(dataset["ECG"])

# %%
sns.scatterplot(dataset["ECG"])

# %%
q1 = dataset["ECG"].quantile(0.25)
q3 = dataset["ECG"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
sns.displot(dataset["EMG"])

# %%
sns.boxplot(dataset["EMG"])

# %%
sns.scatterplot(dataset["EMG"])

# %%
q1 = dataset["EMG"].quantile(0.25)
q3 = dataset["EMG"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
sns.displot(dataset["RESP"])

# %%
sns.boxplot(dataset["RESP"])

# %%
sns.scatterplot(dataset["RESP"])

# %%
q1 = dataset["RESP"].quantile(0.25)
q3 = dataset["RESP"].quantile(0.75)

IQR = q3 - q1


min_range = q1 - (1.5 * IQR)
max_range = q3 + (1.5 * IQR)

print(min_range)
print(max_range)

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
sns.pairplot(dataset , hue="Stress")

# %%
dataset["Stress"].value_counts()
# Out:
# Stress
# High      75000
# Medium    75000
# Low       75000
# Name: count, dtype: int64

# %%
def fetch_stress(x):
    if x == "High":
        return 3
    if x == "Medium":
        return 2
    return 1

# %%
dataset["Stress"] = dataset["Stress"].apply(fetch_stress)

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857       3
# 1  0.020691 -0.004303 -2.252197       2
# 2  0.079330  0.007462  1.069641       1
# 3 -0.040970 -0.018173  2.943420       1
# 4 -0.292007 -0.006729 -0.753784       3

# %%
dataset.corr()["Stress"]
# Out:
# Unnamed: 0.1   -0.471405
# Unnamed: 0     -0.541814
# X               0.635917
# Y               0.388765
# Z               0.675263
# TEMP           -0.587140
# EDA             0.480972
# ECG            -0.013951
# EMG            -0.000704
# RESP           -0.006272
# Stress          1.000000
# Name: Stress, dtype: float64

# %%
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataset.corr(numeric_only=True) , annot= True)
# Out:
# <Axes: >

# %%
x = dataset.drop( columns= ["Stress"])
y =  (dataset["Stress"])

# %%
x
# Out:
#              X       Y       Z       TEMP        EDA       ECG       EMG  \
# 0       0.9050  0.0344  0.0418  31.889160   8.601761 -0.032547  0.013321
# 1       0.9138 -0.1422 -0.0694  32.227600   0.884628  0.020691 -0.004303
# 2       0.4426 -0.2440 -0.8464  32.010742   0.529099  0.079330  0.007462
# 3       0.4248 -0.2466 -0.8498  31.936615   0.453949 -0.040970 -0.018173
# 4       0.9326  0.0386  0.0030  32.217224   7.914734 -0.292007 -0.006729
# ...        ...     ...     ...        ...        ...       ...       ...
# 224995  0.9146  0.0306  0.0108  31.773712   7.951355 -0.045959  0.010117
# 224996  0.9034  0.0406  0.0134  32.932770  10.773087 -0.439774 -0.002747
# 224997  0.8838 -0.0250 -0.2646  33.547455   5.993271 -0.025314 -0.008240
# 224998  0.8866 -0.0290 -0.2592  33.535340   6.023788  0.049530 -0.021378
# 224999  0.8746 -0.0046 -0.2664  33.512695   5.975723 -0.002563 -0.039780
#
#              RESP
# 0       -2.703857
# 1       -2.252197
# 2        1.069641
# 3        2.943420
# 4       -0.753784
# ...           ...
# 224995  -2.450562
# 224996   7.463074
# 224997   2.632141
# 224998  -1.777649
# 224999  14.912415
#
# [225000 rows x 8 columns]

# %%
y
# Out:
# 0         3
# 1         2
# 2         1
# 3         1
# 4         3
#          ..
# 224995    3
# 224996    3
# 224997    2
# 224998    2
# 224999    2
# Name: Stress, Length: 225000, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (225000, 8)
# (225000,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size= 0.2 , random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (180000, 8)
# (45000, 8)
# (180000,)
# (45000,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.metrics import  accuracy_score , confusion_matrix , precision_score

# %%
from sklearn.cluster import KMeans , DBSCAN , HDBSCAN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,ExtraTreesClassifier
from sklearn.svm import SVC

# %%
knn= KNeighborsClassifier (n_neighbors=8)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , knn)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)



print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict))

# %%
dt= DecisionTreeClassifier (max_depth= 10)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , dt)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)



print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
rf= RandomForestClassifier (n_estimators=300,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=25)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , rf)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)


print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
et=  ExtraTreesClassifier (n_estimators=700,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15,
                             bootstrap=True)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , et)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)


print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
ad=  AdaBoostClassifier (n_estimators=50,
                              learning_rate= 1)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , ad)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)


print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
gd=  GradientBoostingClassifier (n_estimators=200)

pipe = Pipeline ([
    ("step1" , ct),
     ("step2" , StandardScaler()),
    ("step3" , gd)
])


pipe.fit (x_train , y_train)


y_predict = pipe.predict (x_test)


print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
svc = SVC (kernel= "rbf" , C = 100 )

pipe = Pipeline ([
    ("step1" , ct),
    ("step2" , StandardScaler()),
    ("step3" , svc)
])


pipe.fit (x_train , y_train)

y_predict = pipe.predict (x_test)

print("\nTRAIN ",pipe.score(x_train,y_train))
print("TEST", pipe.score(x_test,y_test))

print("\nCONFUSION MATRIX\n", confusion_matrix(y_test , y_predict))

print("\nACCURACY SCORE", accuracy_score(y_test , y_predict))
print("PRECISION SCORE", precision_score(y_test , y_predict ,average=None))

# %%
"""
import pickle 

pickle.dump (dataset , open ("" , "wb"))
pickle.dump (pipe , open ("" , "wb"))"""
