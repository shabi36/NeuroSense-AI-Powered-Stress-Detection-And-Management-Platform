# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Stress_Detection_Dataset.csv")
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       X       Y       Z       TEMP       EDA  \
# 0          1101     1887068  0.9050  0.0344  0.0418  31.889160  8.601761
# 1         13705     3407329  0.9138 -0.1422 -0.0694  32.227600  0.884628
# 2          9891     4010604  0.4426 -0.2440 -0.8464  32.010742  0.529099
# 3          7697     4110842  0.4248 -0.2466 -0.8498  31.936615  0.453949
# 4          1229     1634686  0.9326  0.0386  0.0030  32.217224  7.914734
#
#         ECG       EMG      RESP  Stress
# 0 -0.032547  0.013321 -2.703857    High
# 1  0.020691 -0.004303 -2.252197  Medium
# 2  0.079330  0.007462  1.069641     Low
# 3 -0.040970 -0.018173  2.943420     Low
# 4 -0.292007 -0.006729 -0.753784    High

# %%
dataset.drop(columns=["Unnamed: 0" ,"Unnamed: 0.1"] , inplace= True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225000 entries, 0 to 224999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   X       225000 non-null  float64
#  1   Y       225000 non-null  float64
#  2   Z       225000 non-null  float64
#  3   TEMP    225000 non-null  float64
#  4   EDA     225000 non-null  float64
#  5   ECG     225000 non-null  float64
#  6   EMG     225000 non-null  float64
#  7   RESP    225000 non-null  float64
#  8   Stress  225000 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 15.4+ MB

# %%
dataset.head()
# Out:
#         X       Y       Z       TEMP       EDA       ECG       EMG      RESP  \
# 0  0.9050  0.0344  0.0418  31.889160  8.601761 -0.032547  0.013321 -2.703857
# 1  0.9138 -0.1422 -0.0694  32.227600  0.884628  0.020691 -0.004303 -2.252197
# 2  0.4426 -0.2440 -0.8464  32.010742  0.529099  0.079330  0.007462  1.069641
# 3  0.4248 -0.2466 -0.8498  31.936615  0.453949 -0.040970 -0.018173  2.943420
# 4  0.9326  0.0386  0.0030  32.217224  7.914734 -0.292007 -0.006729 -0.753784
#
#    Stress
# 0    High
# 1  Medium
# 2     Low
# 3     Low
# 4    High

# %%
dataset
# Out:
#              X       Y       Z       TEMP        EDA       ECG       EMG  \
# 0       0.9050  0.0344  0.0418  31.889160   8.601761 -0.032547  0.013321
# 1       0.9138 -0.1422 -0.0694  32.227600   0.884628  0.020691 -0.004303
# 2       0.4426 -0.2440 -0.8464  32.010742   0.529099  0.079330  0.007462
# 3       0.4248 -0.2466 -0.8498  31.936615   0.453949 -0.040970 -0.018173
# 4       0.9326  0.0386  0.0030  32.217224   7.914734 -0.292007 -0.006729
# ...        ...     ...     ...        ...        ...       ...       ...
# 224995  0.9146  0.0306  0.0108  31.773712   7.951355 -0.045959  0.010117
# 224996  0.9034  0.0406  0.0134  32.932770  10.773087 -0.439774 -0.002747
# 224997  0.8838 -0.0250 -0.2646  33.547455   5.993271 -0.025314 -0.008240
# 224998  0.8866 -0.0290 -0.2592  33.535340   6.023788  0.049530 -0.021378
# 224999  0.8746 -0.0046 -0.2664  33.512695   5.975723 -0.002563 -0.039780
#
#              RESP  Stress
# 0       -2.703857    High
# 1       -2.252197  Medium
# ...

# %%
dataset.describe()
# Out:
#                    X              Y              Z           TEMP  \
# count  225000.000000  225000.000000  225000.000000  225000.000000
# mean        0.816646      -0.004196      -0.266615      33.607337
# std         0.129467       0.072809       0.314513       1.107826
# min         0.334200      -0.350600      -0.955800      31.270782
# 25%         0.760400      -0.035400      -0.467800      32.561493
# 50%         0.872800       0.008800      -0.254600      33.966125
# 75%         0.906000       0.033000       0.012000      34.437714
# max         1.303800       0.388600       0.732600      35.682922
#
#                  EDA            ECG            EMG           RESP
# count  225000.000000  225000.000000  225000.000000  225000.000000
# mean        5.798486      -0.001085      -0.003175       0.032415
# std         3.143063       0.272254       0.019906       4.058577
# min         0.449371      -1.314606      -0.452957     -36.167908
# ...

# %%
dataset["Stress"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.countplot(x="Stress", data=dataset, palette="coolwarm")
plt.title("Distribution of Stress Levels", fontsize=16)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("Count", fontsize=12)
#plt.savefig("stresslevels.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_2120\2253627185.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Stress", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))
for i, col in enumerate(['TEMP', 'EDA', 'RESP', 'ECG', 'EMG'], 1):
    plt.subplot(3, 2, i)
    sns.boxplot(y=dataset[col], palette="Blues")
    plt.title(f"Outlier Detection - {col}", fontsize=14)
    plt.ylabel(col, fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\4221212297.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=dataset[col], palette="Blues")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\4221212297.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=dataset[col], palette="Blues")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\4221212297.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=dataset[col], palette="Blues")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\4221212297.py:5: FutureWarning:
#
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 12))
for i, col in enumerate(['TEMP', 'EDA', 'RESP'], 1):
    plt.subplot(3, 2, i)
    sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
    plt.title(f"{col} Distribution Across Stress Levels", fontsize=14)
    plt.xlabel("Stress Level", fontsize=12)
    plt.ylabel(col, fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\851979716.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\851979716.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\851979716.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 12))
for i, col in enumerate(['EMG', 'ECG', 'RESP'], 1):
    plt.subplot(3, 2, i)
    sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
    plt.title(f"{col} Distribution Across Stress Levels", fontsize=14)
    plt.xlabel("Stress Level", fontsize=12)
    plt.ylabel(col, fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\569582757.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\569582757.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\569582757.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y=col, data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="RESP", data=dataset, palette="coolwarm")
plt.title(" RESP Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("RESP", fontsize=12)
plt.savefig("resp.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\2619266807.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="RESP", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="TEMP", data=dataset, palette="coolwarm")
plt.title(" TEMP Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("TEMP", fontsize=12)
plt.savefig("temp.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\3290622731.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="TEMP", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="ECG", data=dataset, palette="coolwarm")
plt.title(" ECG Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("ECG", fontsize=12)
plt.savefig("ecg.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\3878659304.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="ECG", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="EDA", data=dataset, palette="coolwarm")
plt.title(" EDA Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("EDA", fontsize=12)
plt.savefig("eda.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\1143015301.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="EDA", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="EMG", data=dataset, palette="coolwarm")
plt.title(" EMG Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("EMG", fontsize=12)
plt.savefig("emg.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\1146938248.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="EMG", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="X", data=dataset, palette="coolwarm")
plt.title(" X Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("X", fontsize=12)
plt.savefig("x.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\2747878089.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="X", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="Y", data=dataset, palette="coolwarm")
plt.title(" Y Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("Y", fontsize=12)
plt.savefig("y.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\2189832519.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="Y", data=dataset, palette="coolwarm")

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))

sns.violinplot(x='Stress', y="Z", data=dataset, palette="coolwarm")
plt.title(" Z Distribution Across Stress Levels", fontsize=14)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("Z", fontsize=12)
plt.savefig("z.png")
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\2335596844.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Stress', y="Z", data=dataset, palette="coolwarm")

# %%
stress_distribution = dataset['Stress'].value_counts()
plt.figure(figsize=(8, 5))
sns.barplot(x=stress_distribution.index, y=stress_distribution.values, palette="coolwarm")
plt.title("Stress Level Distribution", fontsize=16)
plt.xlabel("Stress Level", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\3112927696.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=stress_distribution.index, y=stress_distribution.values, palette="coolwarm")

# %%
data_encoded = dataset.copy()
stress_mapping = {'Low': 0, 'Medium': 1, 'High': 2}
data_encoded['Stress'] = data_encoded['Stress'].map(stress_mapping)


feature_correlation = data_encoded.corr()['Stress'].drop('Stress').sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=feature_correlation.index, y=feature_correlation.values, palette="coolwarm")
plt.title("Correlation of Features with Stress Levels", fontsize=16)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Correlation with Stress", fontsize=12)
plt.xticks(rotation=45)
plt.savefig("cor_stress30.png")
plt.show()

feature_correlation
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_15140\670168706.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_correlation.index, y=feature_correlation.values, palette="coolwarm")
# Z       0.675263
# X       0.635917
# EDA     0.480972
# Y       0.388765
# EMG    -0.000704
# RESP   -0.006272
# ECG    -0.013951
# TEMP   -0.587140
# Name: Stress, dtype: float64

# %%
numerical_features = ['TEMP', 'EDA', 'RESP', 'ECG', 'EMG']

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_features, 1):
    plt.subplot(3, 2, i)
    sns.kdeplot(data=dataset, x=col, hue='Stress', fill=True, common_norm=False, palette="coolwarm")
    plt.title(f"KDE Plot of {col} Across Stress Levels", fontsize=14)
    plt.xlabel(col, fontsize=12)
    plt.ylabel("Density", fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))


sns.kdeplot(data=dataset, x="EDA", hue='Stress', fill=True, common_norm=False, palette="coolwarm")
plt.title("KDE Plot of EDA Across Stress Levels", fontsize=14)
plt.xlabel("EDA", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.savefig("EDAkde.png")
plt.tight_layout()
plt.show()

# %%
corr_matrix = dataset[numerical_features].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Features", fontsize=16)
plt.show()

# %%
plt.scatter(x="TEMP" , y = "RESP" , data=dataset , c)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="TEMP" , y = "EDA" , data=dataset , hue="Stress")
plt.title("EDA v/s TEMP", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="ECG" , y = "EMG" , data=dataset , hue="Stress")
plt.title("EMG v/s ECG", fontsize=14)
plt.savefig("emg_ecg.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="RESP" , y = "EMG" , data=dataset , hue="Stress")
plt.title("EMG v/s RESP", fontsize=14)
plt.savefig("emg_resp.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="ECG" , y = "RESP" , data=dataset , hue="Stress")
plt.title("RESP v/s ECG", fontsize=14)
plt.savefig("resp_ecg.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="EMG" , y = "EDA" , data=dataset , hue="Stress")
plt.title("EDA v/s EMG", fontsize=14)
plt.savefig("eda_emg.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="EDA" , y = "RESP" , data=dataset , hue="Stress")
plt.title("RESP v/s EDA", fontsize=14)
plt.savefig("resp_eda.png")
plt.show()
